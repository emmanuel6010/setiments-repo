# %%
from hokum import *

# %%
# read data
df = read_data_file('../data/raw/amazon.csv', 'csv')

# %%
df.head()
# Out:
#    product_id                                       product_name
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...  \
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399  \
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count
# 0       ₹1,099                 64%    4.2       24,269  \
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product
# 0  High Compatibility : Compatible With iPhone 12...  \
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...  \
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...  \
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...  \
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title
# 0  Satisfied,Charging is really fast,Value for mo...  \
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content
# 0  Looks durable Charging is fine tooNo complains...  \
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link
# 0  https://m.media-amazon.com/images/W/WEBP_40237...  \
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
# generate sentiment score
sentiments = sentiment_data(df, 'review_content')

# %%
sentiments.sample(10)
# Out:
#       product_id                                       product_name
# 1025  B07NCKMXVZ  StyleHouse Lint Remover for Woolen Clothes, El...  \
# 589   B01J0XWYKQ  Logitech B170 Wireless Mouse, 2.4 GHz with USB...
# 713   B09KGV7WSV  KINGONE Upgraded Stylus Pen, iPad Pencil, Ultr...
# 476   B07Q4QV1DL  ELV Aluminum Adjustable Mobile Phone Foldable ...
# 262   B084N1BM9L  Belkin Apple Certified Lightning to USB Charge...
# 95    B093QCY6YJ  ZEBRONICS ZEB-USB150WF1 WiFi USB Mini Adapter ...
# 21    B085194JFL  tizum HDMI to VGA Adapter Cable 1080P for Proj...
# 579   B0BNXFDTZ2  Fire-Boltt Tank 1.85" Bluetooth Calling Smart ...
# 514   B08Y1SJVV5  pTron Solero MB301 3A Micro USB Data & Chargin...
# 359   B09NVPSCQT  Noise ColorFit Pulse Grand Smart Watch with 1....
#
#                                                category discounted_price
# 1025  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...             ₹455  \
# 589   Computers&Accessories|Accessories&Peripherals|...             ₹599
# 713   Electronics|Mobiles&Accessories|MobileAccessor...           ₹2,099
# 476   Electronics|Mobiles&Accessories|MobileAccessor...             ₹269
# 262   Computers&Accessories|Accessories&Peripherals|...           ₹1,299
# 95    Computers&Accessories|NetworkingDevices|Networ...             ₹290
# 21    Electronics|HomeTheater,TV&Video|Accessories|C...             ₹279
# 579         Electronics|WearableTechnology|SmartWatches           ₹2,999
# 514   Computers&Accessories|Accessories&Peripherals|...              ₹99
# 359         Electronics|WearableTechnology|SmartWatches           ₹1,599
#
#      actual_price discount_percentage rating rating_count
# 1025         ₹999                 54%    4.1        3,578  \
# 589          ₹895                 33%    4.4       61,314
# 713        ₹5,999                 65%    4.3       17,129
# 476        ₹1,499                 82%    4.5       28,978
# 262        ₹1,999                 35%    4.4        7,318
# 95           ₹349                 17%    3.7        1,977
# 21           ₹499                 44%    3.7       10,962
# 579       ₹11,999                 75%    4.4          768
# 514       ₹666.66                 85%    3.9       24,870
# 359        ₹3,999                 60%    4.0       30,254
#
#                                           about_product
# 1025  ✅REJUVENATE FABRICS & KEEP TIDY - Restore your...  \
# 589   Reliable Wireless Connection : Enjoy a wireles...
# 713   25MIN FAST CHARGE & UPGRADED NIB - 5 minutes o...
# 476   Multi-angle adjustable stand: Free rotation of...
# 262   The Belkin Difference: Pioneer In Technology A...
# 95    Supports 150Mbps Wireless data transmission ra...
# 21    Superior Stability: Built-in advanced Certifie...
# 579   Largest 1.85" Display : View bigger on the scr...
# 514   Fast Charging & Data Sync: Solero MB301 micro ...
# 359   1.69" grand display: Get the rich immersive vi...
#
#                                                 user_id
# 1025  AGQZ46RQ5YJFVCSGI4BJGNXB7DZA,AFS6PV7PIU6VP4IPE...  \
# 589   AF4AWOIIGQUD4IZ6QNWXVHL6OKTQ,AHGZNSZ5ECVXE3L5R...
# 713   AHJHHQWQ25VCIQHG5XMZN5MRZFYA,AFCFHU6B5RH4YN6DN...
# 476   AGGXWYRLPMULBPR7OXPEV6SNOMIQ,AHBKNSJNHRF22KZYC...
# 262   AHWC76VEMF5NNLUBQCANCBHLBRNQ,AEYYU3KIHUOI2TXTT...
# 95    AFOYOG3YKIOLPTLR3RZNRGUHHEAQ,AENFRNJLSQPJICHCP...
# 21    AEO5FHWNOSFBT554DKQAG4ICBGFQ,AGIQ5Y7Q4MKZ542KK...
# 579   AHBB6UBYHJ5FH2BUFQ2BCXHWQFJQ,AE4S7RU4C77FN2E57...
# 514   AEQ2YMXSZWEOHK2EHTNLOS56YTZQ,AGRVINWECNY7323CW...
# 359   AF3JE3MHGVCOATHASUTMN3VGF3UQ,AEDSNOOD2D6SJAET2...
#
#                                               user_name
# 1025  vipul agnihotri,Banshul Garg,AJIT KUMAR,HIMANS...  \
# 589   Anand,Aditya,Shiva,Saleem Kumar,A Sinha,Arghya...
# 713   Ishwar Singh Sankhla,sai k.,Prathmesh Achareka...
# 476   Shaik John Saida,Nilay Kambli,Amazon Customer,...
# 262   VM,Dilip,The Mango Couple,Jogendra,Shashi Kuma...
# 95    Mohseen Qureshi,Karan,Pranav Anand,Muthukumar,...
# 21    aditya d.,Paranthaman,ashik rahman c,Rajas c.,...
# 579   Adwait Kulkarni,Sarvdeo Pandey,Dulal Roy,Amazo...
# 514   Jayesh,Rajesh k.,Soopy,amazon customer,Aman,Sh...
# 359   Ranjitha Parida,Shubham Pawar,Arul,Lokesh K V,...
#
#                                               review_id
# 1025  R3C4MJ8AHKD85X,R37VBDPMWP0C2Q,RW0LXEHCN4GNH,R1...  \
# 589   R2Z4GQU0ZVOH1G,R3JRYRMKRD0BW0,R2C5DX0ZNNX7Y5,R...
# 713   R1DVF8WQYO780,R2B57KUCWYWDKX,R387VL6JFWOGER,R1...
# 476   R35G82LMN1P1V4,R2R9TCZMPRU2,R2IJXSRMFCQGXD,R3A...
# 262   R1CYG59TJESUGN,R2PIWJZ3LJ0NBY,R17UGMBKG3DWY5,R...
# 95    R32XZQTB1BP0J8,R2NHRHTL743ZMA,R10FKRAEORI9L,RE...
# 21    R1GYK05NN6747O,R1J21BZ29NGQF9,R16JCHEILBYOMW,R...
# 579   R1TK3BJ0V4TTCW,R3CM92MP896BSQ,R1T1NCJKM7VXA6,R...
# 514   R7S8ANNSDPR40,R3CLZFLHVJU26P,RFF7U7MPQFUGR,R1M...
# 359   R3B5HP4PJ8JIOG,R2NS7Z2XUJL73H,R3DLYP0JW3PWDP,R...
#
#                                            review_title
# 1025  Good Product,Nice product,Good product,Good,I ...  \
# 589   Small, not too heavy, good looking.,Quality of...
# 713   Really Satisfied with purchase.,DO NOT BELIEVE...
# 476   Good one,Almost perfect,Go for it,Good product...
# 262   You might be able to get away by using other u...
# 95    Good product,Best produced,Working well as of ...
# 21    Good product ; Average Finishing,Save it purpo...
# 579   Perfect Value for money,Everything is great bu...
# 514   It's pretty good,Average quality,very good and...
# 359   Ranjitha,Good one,Best One!!!,Good and average...
#
#                                          review_content
# 1025  tried on woolen clothes and it really worked. ...  \
# 589   hi guys! bought this yesterday, so haven’t use...
# 713   pros -really like the stylus. it works fine , ...
# 476   good quality. can buy if it’s price is below 2...
# 262   recently ordered other. usb for just 150 rsthe...
# 95    working very nice ok,sahi paise ke hisab se sa...
# 21    this connector has provided as a boon for my o...
# 579   perfect buy for the price of 1999/-after use o...
# 514   it's a good product.,like,very good item stron...
# 359   battery life is low,worth purchase,good perfor...
#
#                                                img_link
# 1025  https://m.media-amazon.com/images/I/415CYtympZ...  \
# 589   https://m.media-amazon.com/images/W/WEBP_40237...
# 713   https://m.media-amazon.com/images/I/31jgUvSar0...
# 476   https://m.media-amazon.com/images/I/31hDWwY8iW...
# 262   https://m.media-amazon.com/images/W/WEBP_40237...
# 95    https://m.media-amazon.com/images/W/WEBP_40237...
# 21    https://m.media-amazon.com/images/W/WEBP_40237...
# 579   https://m.media-amazon.com/images/I/41vQwUamFc...
# 514   https://m.media-amazon.com/images/I/31ew3okQR2...
# 359   https://m.media-amazon.com/images/I/41qqmdUWnh...
#
#                                            product_link  sentiment_score
# 1025  https://www.amazon.in/StyleHouse-Remover-Woole...           0.9881  \
# 589   https://www.amazon.in/Logitech-B170-Wireless-M...           0.9968
# 713   https://www.amazon.in/Upgraded-Precision-Sensi...           0.9962
# 476   https://www.amazon.in/Aluminum-Adjustable-Mobi...           0.9847
# 262   https://www.amazon.in/Belkin-Certified-Lightni...           0.9601
# 95    https://www.amazon.in/ZEBRONICS-ZEB-USB150WF1-...           0.9595
# 21    https://www.amazon.in/Adapter-Projector-Comput...           0.9669
# 579   https://www.amazon.in/Fire-Boltt-Bluetooth-Cal...           0.9952
# 514   https://www.amazon.in/Solero-MB301-Charging-48...           0.9781
# 359   https://www.amazon.in/Noise-ColorFit-Display-M...           0.9877
#
#      sentiment_review_content
# 1025                 positive
# 589                  positive
# 713                  positive
# 476                  positive
# 262                  positive
# 95                   positive
# 21                   positive
# 579                  positive
# 514                  positive
# 359                  positive

# %%
# graph sentiment labels
sentiment_graph(sentiments, 'sentiment_review_content')

# %%
# word cloud
word_cloud_dataframe(df, 'review_content')

# %%
common_words_data(df, 'review_content')

# %%
# recomender system
recommend_data(sentiments, 'product_id', 'B07JW9H4J1', 'user_id', 'product_name','review_content')
# Out:
#      product_id                                            user_id
# 615  B014SZO90Y  AF37SWB5BJAXD6F2Q74M6HJIHADA,AFP7XI3X4GGJVQCYY...  \
#
#                                   product_name
# 615  Duracell Ultra Alkaline AA Battery, 8 Pcs  \
#
#                                         review_content
# 615  nice one, tried on remote mouse and found work...

# %%
sentiments.loc[197].at['review_content']
# Out:
# 'pros- xiomi 5a is best in budget-nice picture quality-very nice audio output- full of featurecons- sometimes tv lags-sometimes stucksin this prize range all tv having cons like this.::overall nice tv,the product in this price range is good but as it is running in android 12 it lags. i hope after few updates the lags problem will be resolved,useless product and useless quality. display issues within 7 months and service center is not upto the mark. go for better brands where quality is assured. i would wish if there was option of negative stars.,uses as connectes tv the picture is very good. i was hopping a best level of song. globaly it is a good product.,https://m.media-amazon.com/images/w/webp_402378-t1/images/i/61spxdbojzl._sy88.jpg,greater then ever,good quality,good 👍'

# %%
technologies = {
    'Courses':["Spark","PySpark","Python","pandas"],
    'Fee' :[20000,25000,22000,30000],
    'Duration':['30days','40days','35days','50days'],
              }
index_labels=['r1','r2','r3','r4']
df1 = pd.DataFrame(technologies,index=index_labels)

technologies2 = {
    'Courses':["Spark","Java","Python","Go"],
    'Discount':[2000,2300,1200,2000]
              }
index_labels2=['r1','r6','r3','r5']
df2 = pd.DataFrame(technologies2,index=index_labels2)
technologies3 = {
    'Instructor': ["Jerry", "Tom", "Smith", "John"],
    'Courses': ["Spark", "Java", "Python", "Scala"]
}
index_labels3 = ['r1','r6','r3','r7']
df3 = pd.DataFrame(technologies3, index=index_labels3)

# %%
df1
# Out:
#     Courses    Fee Duration
# r1    Spark  20000   30days
# r2  PySpark  25000   40days
# r3   Python  22000   35days
# r4   pandas  30000   50days

# %%
df2
# Out:
#    Courses  Discount
# r1   Spark      2000
# r6    Java      2300
# r3  Python      1200
# r5      Go      2000

# %%
df3
# Out:
#    Instructor Courses
# r1      Jerry   Spark
# r6        Tom    Java
# r3      Smith  Python
# r7       John   Scala

# %%
merge_dataframes([df1, df2, df3])
# Out:
#   Courses    Fee Duration  Discount Instructor
# 0   Spark  20000   30days      2000      Jerry
# 1  Python  22000   35days      1200      Smith

# %%
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence
import ffmpeg

# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %%
#pip install ffmpeg

# %%
#pip install ffmpeg-downloader
